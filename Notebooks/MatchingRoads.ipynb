# %%
from pymongo import MongoClient
import numpy as np

import time

import sys
sys.path.append('../scripts/')
sys.path.append('../source/')

# %%
client = MongoClient(host = "mongodb://mbouchouia:cbf20Li34!@mongodb-tp.enst.fr", port=27017)

# %%
from affect_road_to_point_para import Affect_road_to_point
db_name, collection_name, db_osm_name, roads_name = "geolytics", "coyote", "geolytics", "roads"
affect = Affect_road_to_point( db_name, collection_name, db_osm_name, roads_name, 10)

# %%
affect.affect_para(25)
# Out:
# 0 done 0, 1553103050.9597397

# %%
from speed_matrix import SpeedMatrix

# %%
sm = SpeedMatrix("geolytics", "coyote", "geolytics", "ways")

# %%
from mongoConnection import *
import OsmProcessing
segments = OsmProcessing.getSegments(osmWays)
segments = OsmProcessing.setOneWay(segments)

# %%
roads_ids = segments.index.values.tolist()
speeds = sm.get_speed_matrix(15, roads_ids, 14, 19)

# %%
speeds , counts =speeds

# %%
(speeds.notna().sum(axis=1)>(1154*0.8)).sum()
# Out:
# 1246

# %%
speeds.to_pickle("../data/monthsSpeed.pckl")

# %%
counts.to_pickle("../data/monthsCount.pckl")

# %%
speeds.notna().sum(axis=1)
# Out:
# matching_road
# 100319558_0     528
# 100319558_1     164
# 100319559_0       4
# 10062754_0      570
# 10213325_0     1103
# 10273924_0      268
# 10275171_0     1491
# 10275225_0       33
# 104039471_0     218
# 104039472_0       4
# 104039477_0     535
# 104039477_1     528
# 10416752_0     1279
# 10416752_1      533
# 10416753_0      379
# 10416753_1      169
# 10416754_0      331
# 10416754_1       77
# 10416755_0      928
# 10416756_0     1751
# 10416759_0     1336
# 10416760_0        4
# 104862828_0     620
# 104862828_1     327
# 105014634_0    1023
# 10570513_0     1222
# 10647979_0      348
# 10647980_0      801
# 10647980_1      622
# 107065322_0      58
#                ...
# 97419613_1      202
# 97421308_0       56
# 97421308_1       56
# 97421310_0      878
# 97421310_1      258
# 97421319_0     1020
# 97421319_1     1049
# 97421325_0      205
# 97421325_1      268
# 97421789_0      351
# 97421789_1      207
# 97421792_0       88
# 97421792_1        2
# ...

# %%
(speeds.notna().sum(axis=1)>900).sum()

# %%
import pandas as pd

# %%
mergeResults=pd.read_pickle("../data/mergeResults.pckl")
segmentsMeta=pd.read_pickle("../data/segmentsMeta.pckl")

# %%
import Plotting

# %%
segmentsMeta
# Out:
#                 segmentID  changeset                                                key                                                loc  ... maxSpeed         ins          outs    length
# segmentIndex                                                                                                                                ...
# 0              35478524_0          0                               [highway, name, ref]  {'type': 'LineString', 'coordinates': [[-1.552...  ...      NaN        [17]            []  3.339625
# 1             376692521_0          0                               [highway, name, ref]  {'type': 'LineString', 'coordinates': [[-1.531...  ...      NaN          []            []  1.121172
# 2             226057036_0          0                                     [highway, ref]  {'type': 'LineString', 'coordinates': [[-1.564...  ...      NaN   [4, 4935]            []  2.194664
# ...

# %%
fmap = Plotting.getFoliumMap()

Plotting.makePercentageSnapShots(fmap,mergedSegments=segmentsMeta,inversedIndex=mergeResults,segmentsMeta=segments)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-3bdfb845696b> in <module>
#       1 fmap = Plotting.getFoliumMap()
#       2
# ----> 3 Plotting.makePercentageSnapShots(fmap,mergedSegments=segmentsMeta,inversedIndex=mergeResults,segmentsMeta=segments)
#
# /home/dsi/mbouchouia/code/git/PRIM/source/Plotting.py in makePercentageSnapShots(fmap, mergedSegments, inversedIndex, segmentsMeta)
#     275     for i in range(0,11):
#     276
# --> 277         snapShot=mergedSegments[(mergedSegments.nonNullProp>=(i/10))]
#     278         mergeResults = inversedIndex.loc[inversedIndex.isin(snapShot.index)]
#     279         layer = getMergeLayer(fmap,mergeResults,snapShot,segmentsMeta,'layer {:4.2f}%, nbSegmenst= {}'.format(i*10,len(snapShot)))
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
# ...
