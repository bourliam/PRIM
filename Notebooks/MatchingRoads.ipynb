# %%
from pymongo import MongoClient
import numpy as np

import time

import sys
sys.path.append('../scripts/')
sys.path.append('../source/')
client = MongoClient(host = "mongodb://mbouchouia:cbf20Li34!@mongodb-tp.enst.fr", port=27017)
from affect_road_to_point_para import Affect_road_to_point
db_name, collection_name, db_osm_name, roads_name = "geolytics", "coyote", "geolytics", "roads"
affect = Affect_road_to_point( db_name, collection_name, db_osm_name, roads_name, 10)

# %%
# %%time
affect.affect_para(144)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/PRIM/scripts/affect_road_to_point_para.py in affect_para(self, nb_workers)
#     164     self.collection = client[self.db_name][self.collection_name]
#     165
# --> 166     nbPoints = self.collection.count()
#     167
#     168     limit = math.ceil(nbPoints / nb_workers)
#
# ~/.local/lib/python3.6/site-packages/pymongo/collection.py in count(self, filter, session, **kwargs)
#    1764         collation = validate_collation_or_none(kwargs.pop('collation', None))
#    1765         cmd.update(kwargs)
# -> 1766         return self._count(cmd, collation, session)
#    1767
#    1768     def create_indexes(self, indexes, session=None, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pymongo/collection.py in _count(self, cmd, collation, session)
#    1561     def _count(self, cmd, collation=None, session=None):
#    1562         """Internal count helper."""
# -> 1563         with self._socket_for_reads(session) as (sock_info, slave_ok):
#    1564             res = self._command(
#    1565                 sock_info,
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _socket_for_reads(self, read_preference)
#    1097         topology = self._get_topology()
#    1098         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1099         server = topology.select_server(read_preference)
#    1100
#    1101         with self._get_socket(server) as sock_info:
#
# ~/.local/lib/python3.6/site-packages/pymongo/topology.py in select_server(self, selector, server_selection_timeout, address)
#     222         return random.choice(self.select_servers(selector,
#     223                                                  server_selection_timeout,
# --> 224                                                  address))
#     225
#     226     def select_server_by_address(self, address,
#
# ~/.local/lib/python3.6/site-packages/pymongo/topology.py in select_servers(self, selector, server_selection_timeout, address)
#     181         with self._lock:
#     182             server_descriptions = self._select_servers_loop(
# --> 183                 selector, server_timeout, address)
#     184
#     185             return [self.get_server_by_address(sd.address)
#
# ~/.local/lib/python3.6/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     197             if timeout == 0 or now > end_time:
#     198                 raise ServerSelectionTimeoutError(
# --> 199                     self._error_message(selector))
#     200
#     201             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused

# %%
import sys
sys.path.append('../scripts/')
sys.path.append('../source/')
import OsmProcessing
osmWays = client.geolytics.ways
segments=OsmProcessing.getSegments(osmWays)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f5ca4e54c039> in <module>
#       4 import OsmProcessing
#       5 osmWays = client.geolytics.ways
# ----> 6 segments=OsmProcessing.getSegments(osmWays)
#
# ~/PRIM/source/OsmProcessing.py in getSegments(osmWays, innerBox, innerTags, outerBox, outerTags)
#      61     )
#      62
# ---> 63     outerRocadeDF=pd.DataFrame(list(cur))
#      64     segments=pd.concat([innerRocadeDF,outerRocadeDF])
#      65     segments.drop_duplicates('_id',inplace=True)
#
# ~/.local/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/.local/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1124                                         self.__collection.database.client,
#    1125                                         self.__max_await_time_ms)
# -> 1126                 self.__send_message(g)
#    1127
#    1128         return len(self.__data)
#
# ~/.local/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     929             try:
#     930                 response = client._send_message_with_response(
# --> 931                     operation, exhaust=self.__exhaust, address=self.__address)
#     932                 self.__address = response.address
#     933                 if self.__exhaust:
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _send_message_with_response(self, operation, exhaust, address)
#    1143             self.__all_credentials,
#    1144             self._event_listeners,
# -> 1145             exhaust)
#    1146
#    1147     def _reset_on_error(self, server, func, *args, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pymongo/mongo_client.py in _reset_on_error(self, server, func, *args, **kwargs)
#    1154         """
#    1155         try:
# -> 1156             return func(*args, **kwargs)
#    1157         except NetworkTimeout:
#    1158             # The socket has been closed. Don't reset the server.
#
# ~/.local/lib/python3.6/site-packages/pymongo/server.py in send_message_with_response(self, operation, set_slave_okay, all_credentials, listeners, exhaust)
#     104             try:
#     105                 sock_info.send_message(data, max_doc_size)
# --> 106                 reply = sock_info.receive_message(request_id)
#     107             except Exception as exc:
#     108                 if publish:
#
# ~/.local/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     610                                    self.max_message_size)
#     611         except BaseException as error:
# --> 612             self._raise_connection_failure(error)
#     613
#     614     def _raise_if_not_writable(self, unacknowledged):
#
# ~/.local/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# ~/.local/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     608         try:
#     609             return receive_message(self.sock, request_id,
# --> 610                                    self.max_message_size)
#     611         except BaseException as error:
#     612             self._raise_connection_failure(error)
#
# ~/.local/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     171     # Ignore the response's request id.
#     172     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 173         _receive_data_on_socket(sock, 16))
#     174     # No request_id for exhaust cursor "getMore".
#     175     if request_id is not None:
#
# ~/.local/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     230         while bytes_read < length:
#     231             try:
# --> 232                 chunk_length = sock.recv_into(mv[bytes_read:])
#     233             except (IOError, OSError) as exc:
#     234                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
segments
# Out:
#            changeset                                                key  \
# _id
# 35478524           0                               [highway, name, ref]
# 376692521          0                               [highway, name, ref]
# 226057036          0                                     [highway, ref]
# 302201368          0                   [highway, name, oneway, surface]
# 317106155          0                       [highway, name, ref, source]
# 543380718          0                       [highway, name, ref, source]
# 220667241          0                [bridge, highway, layer, note, ref]
# 220667242          0                               [highway, name, ref]
# 220665949          0                       [ref, name, source, highway]
# 220665936          0                                  [oneway, highway]
# 220665937          0                             [highway, oneway, ref]
# 220665940          0                             [highway, oneway, ref]
# 220665942          0                                     [ref, highway]
# 220665945          0                             [highway, oneway, ref]
# 220665946          0                             [highway, oneway, ref]
# 220665947          0                                  [highway, oneway]
# 220665951          0                                [highway, junction]
# 35478525           0                       [highway, name, ref, source]
# 24956576           0                               [highway, name, ref]
# 311821852          0                     [highway, maxspeed, name, ref]
# 25205548           0                       [highway, name, oneway, ref]
# 376706291          0            [highway, maxspeed, name, ref, traffic]
# 326907911          0                           [highway, maxspeed, ref]
# 311931228          0                                  [oneway, highway]
# 311931226          0                                  [oneway, highway]
# 220492650          0       [highway, maxspeed, maxweight, ref, traffic]
# 311931215          0       [highway, maxspeed, maxweight, ref, traffic]
# 311931198          0                  [highway, maxspeed, ref, traffic]
# 25205542           0                                    [highway, name]
# 5077942            0                       [highway, junction, traffic]
# ...              ...                                                ...
# 405670621          0  [highway, maxspeed, motorroad, oneway, ref, tr...
# 617483186          0  [highway, maxspeed, motorroad, oneway, ref, tr...
# 24395016           0  [highway, maxspeed, motorroad, oneway, ref, tr...
# 24395018           0  [highway, maxspeed, motorroad, oneway, ref, tr...
# 5077945            0  [highway, lanes, legal, lit, maxspeed, name, o...
# 25668255           0  [highway, lanes, legal, lit, maxspeed, name, o...
# 618763758          0     [highway, junction, lanes, lit, name, traffic]
# 220699015          0  [highway, lanes, legal, lit, maxspeed, name, o...
# 618763662          0  [foot, highway, junction, lanes, lit, maxspeed...
# 618763665          0  [foot, highway, junction, lanes, lit, maxspeed...
# 618763666          0  [foot, highway, junction, lanes, lit, maxspeed...
# 618763667          0  [foot, highway, junction, lanes, lit, maxspeed...
# 5077946            0  [foot, highway, junction, lanes, lit, maxspeed...
# 618763663          0  [foot, highway, junction, lanes, lit, maxspeed...
# 625275414          0  [highway, lanes, legal, lit, maxspeed, name, o...
# 618283429          0  [highway, lanes, legal, lit, maxspeed, name, o...
# 625275415          0  [highway, lanes, legal, lit, maxspeed, name, o...
# 48487583           0  [ref, lanes, layer, rural, bridge, oneway, hig...
# 48487581           0  [ref, lanes, layer, rural, bridge, oneway, hig...
# 51156852           0  [ref, lanes, rural, oneway, highway, int_ref, ...
# 220935612          0  [highway, lanes, legal, maxspeed, name, oneway...
# 362465502          0  [highway, lanes, legal, maxspeed, name, oneway...
# 360147392          0  [highway, lanes, legal, maxspeed, name, oneway...
# 362465503          0  [highway, lanes, legal, maxspeed, name, oneway...
# 237029393          0  [highway, lanes, legal, maxspeed, name, oneway...
# 360147393          0  [bridge, highway, lanes, layer, legal, maxspee...
# 360147394          0  [bridge, highway, lanes, layer, legal, maxspee...
# 360147395          0  [highway, lanes, legal, maxspeed, name, oneway...
# 5077947            0  [highway, lanes, legal, lit, maxspeed, name, o...
# 237029394          0  [highway, lanes, legal, lit, maxspeed, name, o...
#
#                                                          loc  \
# _id
# 35478524   {'type': 'LineString', 'coordinates': [[-1.552...
# 376692521  {'type': 'LineString', 'coordinates': [[-1.531...
# 226057036  {'type': 'LineString', 'coordinates': [[-1.564...
# 302201368  {'type': 'LineString', 'coordinates': [[-1.536...
# 317106155  {'type': 'LineString', 'coordinates': [[-1.579...
# 543380718  {'type': 'LineString', 'coordinates': [[-1.564...
# 220667241  {'type': 'LineString', 'coordinates': [[-1.565...
# 220667242  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665949  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665936  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665937  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665940  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665942  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665945  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665946  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665947  {'type': 'LineString', 'coordinates': [[-1.565...
# 220665951  {'type': 'LineString', 'coordinates': [[-1.565...
# 35478525   {'type': 'LineString', 'coordinates': [[-1.560...
# 24956576   {'type': 'LineString', 'coordinates': [[-1.583...
# 311821852  {'type': 'LineString', 'coordinates': [[-1.564...
# 25205548   {'type': 'LineString', 'coordinates': [[-1.564...
# 376706291  {'type': 'LineString', 'coordinates': [[-1.598...
# 326907911  {'type': 'LineString', 'coordinates': [[-1.599...
# 311931228  {'type': 'LineString', 'coordinates': [[-1.577...
# 311931226  {'type': 'LineString', 'coordinates': [[-1.578...
# 220492650  {'type': 'LineString', 'coordinates': [[-1.605...
# 311931215  {'type': 'LineString', 'coordinates': [[-1.604...
# 311931198  {'type': 'LineString', 'coordinates': [[-1.603...
# 25205542   {'type': 'LineString', 'coordinates': [[-1.604...
# 5077942    {'type': 'LineString', 'coordinates': [[-1.604...
# ...                                                      ...
# 405670621  {'type': 'LineString', 'coordinates': [[-1.614...
# 617483186  {'type': 'LineString', 'coordinates': [[-1.612...
# 24395016   {'type': 'LineString', 'coordinates': [[-1.608...
# 24395018   {'type': 'LineString', 'coordinates': [[-1.612...
# 5077945    {'type': 'LineString', 'coordinates': [[-1.607...
# 25668255   {'type': 'LineString', 'coordinates': [[-1.608...
# 618763758  {'type': 'LineString', 'coordinates': [[-1.608...
# 220699015  {'type': 'LineString', 'coordinates': [[-1.606...
# 618763662  {'type': 'LineString', 'coordinates': [[-1.607...
# 618763665  {'type': 'LineString', 'coordinates': [[-1.607...
# 618763666  {'type': 'LineString', 'coordinates': [[-1.607...
# 618763667  {'type': 'LineString', 'coordinates': [[-1.607...
# 5077946    {'type': 'LineString', 'coordinates': [[-1.608...
# 618763663  {'type': 'LineString', 'coordinates': [[-1.607...
# 625275414  {'type': 'LineString', 'coordinates': [[-1.607...
# 618283429  {'type': 'LineString', 'coordinates': [[-1.606...
# 625275415  {'type': 'LineString', 'coordinates': [[-1.602...
# 48487583   {'type': 'LineString', 'coordinates': [[-1.689...
# 48487581   {'type': 'LineString', 'coordinates': [[-1.690...
# 51156852   {'type': 'LineString', 'coordinates': [[-1.690...
# 220935612  {'type': 'LineString', 'coordinates': [[-1.591...
# 362465502  {'type': 'LineString', 'coordinates': [[-1.601...
# 360147392  {'type': 'LineString', 'coordinates': [[-1.600...
# 362465503  {'type': 'LineString', 'coordinates': [[-1.601...
# 237029393  {'type': 'LineString', 'coordinates': [[-1.600...
# 360147393  {'type': 'LineString', 'coordinates': [[-1.600...
# 360147394  {'type': 'LineString', 'coordinates': [[-1.600...
# 360147395  {'type': 'LineString', 'coordinates': [[-1.600...
# 5077947    {'type': 'LineString', 'coordinates': [[-1.602...
# 237029394  {'type': 'LineString', 'coordinates': [[-1.600...
# 362465502  [500929150, 5829902582, 3859510230, 5829902602...
# 360147392                [3647506818, 1857143221, 500929150]
# 362465503                [500929143, 1857143222, 3647506819]
# 237029393  [1857143227, 3647506877, 3647506864, 582741723...
# 360147393                           [3647506822, 3647506818]
# 360147394                           [3647506819, 3647506821]
# 360147395  [3647506821, 1857143225, 3647506830, 364750684...
# 5077947    [1857143256, 5827417222, 5827417223, 185714323...
# 237029394  [1857143229, 5827417228, 5827417227, 582741722...
#
#                                                    relations  \
# _id
# 35478524                                                 NaN
# 376692521                                                NaN
# 226057036                                                NaN
# 302201368                                                NaN
# 317106155                                                NaN
# 543380718                                                NaN
# 220667241                                                NaN
# 220667242                                                NaN
# 220665949                                                NaN
# 220665936                                                NaN
# 220665937                                                NaN
# 220665940                                                NaN
# 220665942                                                NaN
# 220665945                                                NaN
# 220665946                                                NaN
# 220665947                                                NaN
# 220665951                                                NaN
# 35478525                                                 NaN
# 24956576                                                 NaN
# 311821852                                                NaN
# 25205548                                                 NaN
# 376706291                                 [4259852, 8737111]
# 326907911                                                NaN
# 311931228                                                NaN
# 311931226                                                NaN
# 220492650                                                NaN
# 311931215                                                NaN
# 311931198                        [4259852, 5612213, 8737111]
# 25205542                                                 NaN
# 5077942                                   [4259852, 8737111]
# ...                                                      ...
# 405670621                                                NaN
# 617483186                                                NaN
# 24395016                                                 NaN
# 24395018                                                 NaN
# 5077945    [405695, 1743233, 1743320, 2921325, 4259848, 5...
# 25668255   [405691, 1743253, 1743319, 4259846, 5339045, 5...
# 618763758                        [2921325, 6599416, 6778023]
# 220699015                        [1743320, 2921325, 4259848]
# 618763662  [405691, 1743253, 2921325, 5339045, 5339191, 6...
# 618763665  [405695, 1743233, 1743320, 2921325, 4259848, 5...
# 618763666               [1743320, 2921325, 4259848, 6778023]
# 618763667  [405691, 1743253, 1743320, 2921325, 4259848, 5...
# 5077946    [405691, 1743253, 1743319, 2921325, 4259846, 5...
# 618763663                                 [2921325, 6778023]
# 625275414                        [1743319, 4259846, 6778023]
# 618283429                        [1743320, 2921325, 4259848]
# 625275415                        [1743320, 2921325, 4259848]
# 48487583   [72825, 1268731, 2295030, 2455384, 4259847, 42...
# 48487581   [72825, 405676, 2295029, 2455383, 5349259, 546...
# 51156852   [72825, 1268731, 2295030, 2455384, 4259847, 42...
# 220935612                                 [2921325, 4259848]
# 362465502                                 [4259846, 6778023]
# 360147392                        [1743319, 4259846, 6778023]
# 362465503                        [1743320, 2921325, 4259848]
# 237029393                        [1743319, 4259846, 6778023]
# 360147393                        [1743319, 4259846, 6778023]
# 360147394                        [1743320, 2921325, 4259848]
# 360147395                        [1743320, 2921325, 4259848]
# 5077947                          [1743319, 4259846, 6778023]
# 237029394                        [1743320, 2921325, 4259848]
#
#                                                          tag  \
# _id
# 35478524   {'highway': 'tertiary', 'name': 'Route de Cess...
# 376692521  {'highway': 'tertiary', 'name': 'Route des Gré...
# 226057036            {'highway': 'tertiary', 'ref': 'D 286'}
# 302201368  {'highway': 'tertiary', 'name': 'Route de la G...
# 317106155  {'highway': 'tertiary', 'name': 'Route de Doml...
# 543380718  {'highway': 'tertiary', 'name': 'Route de Doml...
# 220667241  {'bridge': 'yes', 'highway': 'tertiary', 'laye...
# 220667242  {'highway': 'tertiary', 'name': 'Route de Doml...
# 220665949  {'ref': 'D 32', 'name': 'Route de Domloup', 's...
# 220665936           {'oneway': 'yes', 'highway': 'tertiary'}
# 220665937  {'highway': 'tertiary', 'oneway': 'yes', 'ref'...
# 220665940  {'highway': 'tertiary', 'oneway': 'yes', 'ref'...
# 220665942            {'ref': 'D 286', 'highway': 'tertiary'}
# 220665945  {'highway': 'tertiary', 'oneway': 'yes', 'ref'...
# 220665946  {'highway': 'tertiary', 'oneway': 'yes', 'ref'...
# 220665947           {'highway': 'tertiary', 'oneway': 'yes'}
# 220665951  {'highway': 'tertiary', 'junction': 'roundabout'}
# 35478525   {'highway': 'tertiary', 'name': 'Route de Cess...
# 24956576   {'highway': 'tertiary', 'name': 'Route de la F...
# 311821852  {'highway': 'tertiary', 'maxspeed': '80', 'nam...
# 25205548   {'highway': 'tertiary', 'name': 'Route de la R...
# 376706291  {'highway': 'secondary', 'maxspeed': '80', 'na...
# 326907911  {'highway': 'tertiary', 'maxspeed': '80', 'ref...
# 311931228           {'oneway': 'yes', 'highway': 'tertiary'}
# 311931226           {'oneway': 'yes', 'highway': 'tertiary'}
# 220492650  {'highway': 'secondary', 'maxspeed': '70', 'ma...
# 311931215  {'highway': 'secondary', 'maxspeed': '50', 'ma...
# 311931198  {'highway': 'secondary', 'maxspeed': '80', 're...
# 25205542   {'highway': 'tertiary', 'name': 'Avenue Charle...
# 5077942    {'highway': 'secondary', 'junction': 'roundabo...
# ...                                                      ...
# 405670621  {'highway': 'primary', 'maxspeed': '70', 'moto...
# 617483186  {'highway': 'primary', 'maxspeed': '70', 'moto...
# 24395016   {'highway': 'primary', 'maxspeed': '70', 'moto...
# 24395018   {'highway': 'primary', 'maxspeed': '70', 'moto...
# 5077945    {'highway': 'trunk', 'lanes': '2', 'legal': 'm...
# 25668255   {'highway': 'trunk', 'lanes': '2', 'legal': 'm...
# 618763758  {'highway': 'primary', 'junction': 'roundabout...
# 220699015  {'highway': 'trunk', 'lanes': '2', 'legal': 'c...
# 618763662  {'foot': 'no', 'highway': 'primary', 'junction...
# 618763665  {'foot': 'no', 'highway': 'primary', 'junction...
# 618763666  {'foot': 'no', 'highway': 'primary', 'junction...
# 618763667  {'foot': 'no', 'highway': 'primary', 'junction...
# 5077946    {'foot': 'no', 'highway': 'primary', 'junction...
# 618763663  {'foot': 'no', 'highway': 'primary', 'junction...
# 625275414  {'highway': 'trunk', 'lanes': '2', 'legal': 'c...
# 618283429  {'highway': 'trunk', 'lanes': '2', 'legal': 'c...
# 625275415  {'highway': 'trunk', 'lanes': '2', 'legal': 'c...
# 48487583   {'ref': 'N 137', 'lanes': '2', 'layer': '1', '...
# 48487581   {'ref': 'N 137', 'lanes': '2', 'layer': '1', '...
# 51156852   {'ref': 'N 137', 'lanes': '2', 'rural': '1', '...
# 220935612  {'highway': 'trunk', 'lanes': '2', 'legal': 'm...
#
# 360147392  2018-09-18T14:05:36Z        9
# 362465503  2018-09-18T14:05:37Z        8
# 237029393  2018-09-18T14:05:32Z       10
# 360147393  2018-09-18T14:05:37Z        9
# 360147394  2018-09-18T14:05:37Z        9
# 360147395  2018-09-18T14:05:37Z        9
# 5077947    2018-09-18T14:05:16Z       29
# 237029394  2018-09-18T14:05:32Z       13
#
# [5231 rows x 8 columns]

# %%
import osmMerger

# %%
segs = osmMerger.mergeSegments()
# Out:
# Computing raw data :
# first time call or reset : starting counter
# getting segments and meta :
# time spent 32.0 s
# getting speed matrix :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c5e41e8e1fca> in <module>
# ----> 1 segs = osmMerger.mergeSegments()
#
# ~/PRIM/source/osmMerger.py in mergeSegments(minValidData, weights, speedsMx)
#     386         sm = SpeedMatrix("geolytics", "coyote", "geolytics", "ways")
#     387         roads_ids = segments.index.values.tolist()
# --> 388         speeds = sm.get_speed_matrix(15, roads_ids, 17, 20)
#     389
#     390     else :
#
# ~/PRIM/scripts/speed_matrix.py in get_speed_matrix(self, timeframe, road_ids, hour_start, hour_end)
#     117                             "matching_road": {"$first": {"$concat": [{"$toString": "$matching_road"}, "_", {"$toString": "$heading_road"}]}},
#     118                         }
# --> 119                     }], allowDiskUse=True
#     120             ))
#     121         )
#
# ~/.local/lib/python3.6/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    2395                                    session=s,
#    2396                                    explicit_session=session is not None,
# -> 2397                                    **kwargs)
#    2398
#    2399     def aggregate_raw_batches(self, pipeline, **kwargs):
#
# ~/.local/lib/python3.6/site-packages/pymongo/collection.py in _aggregate(self, pipeline, cursor_class, first_batch_size, session, explicit_session, **kwargs)
#    2302                 collation=collation,
#    2303                 session=session,
# -> 2304                 client=self.__database.client)
#    2305
#    2306             if "cursor" in result:
#
# ~/.local/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     582         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     583         except BaseException as error:
# --> 584             self._raise_connection_failure(error)
#     585
#     586     def send_message(self, message, max_doc_size):
#
# ~/.local/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     743             _raise_connection_failure(self.address, error)
#     744         else:
# --> 745             raise error
#     746
#     747     def __eq__(self, other):
#
# ~/.local/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# ~/.local/lib/python3.6/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     139             response_doc = {"ok": 1}
#     140         else:
# --> 141             reply = receive_message(sock, request_id)
#     142             unpacked_docs = reply.unpack_response(codec_options=codec_options)
#     143
#
# ~/.local/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock, request_id, max_message_size)
#     171     # Ignore the response's request id.
#     172     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 173         _receive_data_on_socket(sock, 16))
#     174     # No request_id for exhaust cursor "getMore".
#     175     if request_id is not None:
#
# ~/.local/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock, length)
#     230         while bytes_read < length:
#     231             try:
# --> 232                 chunk_length = sock.recv_into(mv[bytes_read:])
#     233             except (IOError, OSError) as exc:
#     234                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:
